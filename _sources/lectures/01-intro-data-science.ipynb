# %% [markdown]
# # Introduction to Data Science

# %% [markdown]
# ```{figure} ../img/ds-ai.jpeg
# ---
# width: 80%
# name: ds-ai
# ---
# Generated by AI.
# ```

# %% [markdown]
# ## "Pillars" of Data Science
# Data Science is a very broad discipline, but generally the field is guided by four essential pillars:
#
# - Domain knowledge
# - Mathematics and Statistics
# - Computer Science
# - Communications

# %% [markdown]
# ## How this class fits into your curriculum
# [Data Science and Engineering Minor curriculum](https://www.mccormick.northwestern.edu/data-science-engineering/curriculum/)

# %% [markdown]
# ## Who are you?
# Tell us a little about yourself:
#
# 1. Your name
# 2. Your major
# 3. What is an example of problems you want to solve?
# 4. What do you expect to get out from this class?
