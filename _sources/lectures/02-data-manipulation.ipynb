# %% [markdown]
# # Data manipulation with `pandas`
#
# This document includes a sequence of notebooks to introduce data manipulation in Python using the `pandas` library.
#
# ## Basic building blocks
# `pandas` works with tabular data (rows and columns) through `Series`, `DataFrame` objects.

# %%
import pandas as pd

meteor = pd.read_csv('../data/Meteorite_Landings.csv')

# %% [markdown]
# *Source: [NASA Open Data Portal](https://data.nasa.gov/Space-Science/Meteorite-Landings/gh4g-9sfh/data_preview)*

# %%
type(meteor)

# %% [markdown]
# A `DataFrame` is the basic "spreadsheet" or "table" used in Python.  A `DataFrame` object is composed of one or more `Series` objects (columns), and indexed by `Index` (rows).

# %%
# head.() shows us the first several rows
meteor.head()

# %%
# investigate a column (note its type)
print(type(meteor.name))

meteor.name.head()

# %%
# investigate how the columns are labeled
meteor.columns

# %%
# investigate how the rows are indexed
meteor.index

# %% [markdown]
# ## DataFrame sources
#
# `DataFrame`s can be created from reading a file, scraping the web, and/or API requests.

# %% [markdown]
# ### Reading from a file

# %%
import pandas as pd

meteor = pd.read_csv('../data/Meteorite_Landings.csv')

# %% [markdown]
# ### API requests (more details later)

# %%
import requests

response = requests.get(
    'https://data.nasa.gov/resource/gh4g-9sfh.json',
    params={'$limit': 50000}  # Depending on the API, there may be a default limit of records one can obtain
)

# %%
response  # A 200 exit code indicates success

# %% [markdown]
# *Tip:* A list of HTTP GET exit codes is available at https://developer.mozilla.org/en-US/docs/Web/HTTP/Status.

# %%
response.ok  # checks ok flag

# %%
# Extract data if request is successful
if response.ok:
    payload = response.json()
else:
    print(f'Request failed with exit code {response.status_code}.')
    payload = None

# %%
# Load into DataFrame
meteor_json = pd.DataFrame(payload)
meteor_json.head()

# %%
# Removing auto-computed columns
mask = meteor_json.columns.str.contains('@computed_region', regex=True)

columns_to_drop = meteor_json.columns[mask]

# %%
meteor_json = meteor_json.drop(columns=columns_to_drop)

# %%
# storing downloaded data into files
    # meteor_json.to_csv('meteor.csv')

# %% [markdown]
# ## Basic inspection

# %% [markdown]
# ### What type of data are available in the dataframe? Are there missing data?

# %%
meteor.info()

# %% [markdown]
# ### How much data are available?

# %%
meteor.shape

# %% [markdown]
# ## Subsetting and indexing
#
# Effectively extracting data from a full dataset requires fluency in how the `DataFrame` can be subsetted and how it is indexed.

# %% [markdown]
# ### Calling a column by attributes (if valid)

# %%
meteor.recclass

# %% [markdown]
# ### Calling a column by keys

# %%
meteor['mass (g)']

# %% [markdown]
# ### Multiple columns by name

# %%
meteor[['name', 'mass (g)']]

# %% [markdown]
# ### Selecting rows

# %%
meteor[5:10]  # end-exclusive

# %% [markdown]
# ### Indexing with `.loc[]`, `iloc[]`
#
# - `.loc[]` indexes by row labels
# - `.iloc[]` indexes by indices

# %%
meteor.loc[0:4, 'name':'mass (g)']

# %%
meteor.iloc[0:4, 0:5]

# %% [markdown]
# ### Filtering or subsetting by condition
# Selection by condition can be performed by creating a Boolean *mask* with True/False values to specify which rows/columns to select.

# %%
# select records with heavy meteor (mass > 10^7) that are found (fall = 'Found')
mask = (meteor['mass (g)'] > 1e7) & (meteor.fall == 'Found')
mask

# %%
meteor[mask]

# %% [markdown]
# **Note:** Each condition is surrounded by parentheses, and we use bitwise operator (`&`, `|`, `~`) instead of logical operators (`and`, `or`, `not`).

# %%
# negation of a mask
meteor[~mask]

# %% [markdown]
# **Note**: Boolean masks can be used with `loc[]` and `iloc[]` as well.

# %% [markdown]
# ## Calculating summary statistics
# This section discusses preliminary calculations before conducting further data analysis.

# %% [markdown]
# ### How many of the meteorites were observed falling vs found?

# %%
meteor.fall.value_counts()

# %%
meteor.fall.value_counts(normalize=True)

# %% [markdown]
# ### Behavior of mass of a meterorite?

# %%
meteor['mass (g)'].mean()

# %%
meteor['mass (g)'].quantile([0.01, 0.05, 0.5, 0.95, 0.99])

# %%
meteor['mass (g)'].max()

# %%
# sometimes helpful to locate the other information related to a particular entry
meteor.loc[meteor['mass (g)'].idxmax()]  # note the "index" of max()

# %% [markdown]
# ### How many unique classes are in this dataset?

# %%
meteor.recclass.nunique()

# %% [markdown]
# ### General statistics
# The `.describe()` method includes numeric columns by default.  Here we can force it to include all columns.

# %%
meteor.describe(include='all')

# %% [markdown]
# **Note**: `NaN` values signify missing data. For instance, the fall column contains strings, so there is no value for mean; likewise, mass (g) is numeric, so we don't have entries for the categorical summary statistics (unique, top, freq).

# %% [markdown]
# ## Practice 1
#
# The following command downloads a `.parquet` file containing NYC Yellow Taxi data, a common storage format for moderate to large datasets.

# %%
# !curl -O https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet

# %%
taxi = pd.read_XXXXXXX('yellow_tripdata_2024-01.parquet')

# %% [markdown]
# 1. Examine the first five rows of the dataset.

# %% [markdown]
# 2. How much data are included in this dataset?

# %% [markdown]
# 3. Calculate summary statistics for the `fare_amount`, `tolls_amount`, and `tip_amount`.  Do they add up to the `total_amount`?

# %% [markdown]
# 4. Find the trip that has the longest trip by distance (`trip_distance`).

# %% [markdown]
# 5. Compare the average `total_amount` for short versus long trips (short trip has `trip_distance` < 10).  Make sure we do not include zero-distance trips.

# %% [markdown]
# ---

# %% [markdown]
# ## Data cleaning
# We will cover some common transformations that facilitate data analysis, including rearranging columns, type conversion, and sorting.

# %%
minitaxi = taxi.sample(10000)  # down-sample our dataset for illustration

# %%
minitaxi.shape
# Out:
# (10000, 19)

# %%
minitaxi.head()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1463982         2  2024-01-17 18:24:02   2024-01-17 18:38:47              1.0
# 279981          2  2024-01-04 17:05:34   2024-01-04 17:15:20              5.0
# 1520803         2  2024-01-18 11:13:37   2024-01-18 11:20:40              1.0
# 1661790         1  2024-01-19 18:34:09   2024-01-19 18:45:45              1.0
# 359292          2  2024-01-05 13:08:13   2024-01-05 13:11:19              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 1463982           1.92         1.0                  N           113
# 279981            1.45         1.0                  N           140
# 1520803           1.37         1.0                  N           239
# 1661790           2.90         1.0                  N           170
# 359292            0.57         1.0                  N           142
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 1463982           148             1         14.9    2.5      0.5        2.25
# 279981            162             2         10.7    2.5      0.5        0.00
# 1520803           236             1          9.3    0.0      0.5        2.66
# 1661790             4             1         14.9    5.0      0.5        4.25
# 359292            239             2          5.1    0.0      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 1463982           0.0                    1.0         23.65
# 279981            0.0                    1.0         17.20
# 1520803           0.0                    1.0         15.96
# 1661790           0.0                    1.0         25.65
# 359292            0.0                    1.0          9.10
#
#          congestion_surcharge  Airport_fee
# 1463982                   2.5          0.0
# 279981                    2.5          0.0
# 1520803                   2.5          0.0
# 1661790                   2.5          0.0
# 359292                    2.5          0.0

# %% [markdown]
# ### Dropping columns

# %%
# drop all id columns and the store_and_fwd_flag column
mask = minitaxi.columns.str.contains('ID$|store_and_fwd_flag', regex=True)
columns_to_drop = minitaxi.columns[mask]
columns_to_drop
# Out:
# Index(['VendorID', 'RatecodeID', 'PULocationID', 'DOLocationID'], dtype='object')

# %%
minitaxi = minitaxi.drop(columns=columns_to_drop)
minitaxi.head()
# Out:
#         tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1463982  2024-01-17 18:24:02   2024-01-17 18:38:47              1.0
# 279981   2024-01-04 17:05:34   2024-01-04 17:15:20              5.0
# 1520803  2024-01-18 11:13:37   2024-01-18 11:20:40              1.0
# 1661790  2024-01-19 18:34:09   2024-01-19 18:45:45              1.0
# 359292   2024-01-05 13:08:13   2024-01-05 13:11:19              1.0
#
#          trip_distance  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 1463982           1.92             1         14.9    2.5      0.5        2.25
# 279981            1.45             2         10.7    2.5      0.5        0.00
# 1520803           1.37             1          9.3    0.0      0.5        2.66
# 1661790           2.90             1         14.9    5.0      0.5        4.25
# 359292            0.57             2          5.1    0.0      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 1463982           0.0                    1.0         23.65
# 279981            0.0                    1.0         17.20
# 1520803           0.0                    1.0         15.96
# 1661790           0.0                    1.0         25.65
# 359292            0.0                    1.0          9.10
#
#          congestion_surcharge  Airport_fee
# 1463982                   2.5          0.0
# 279981                    2.5          0.0
# 1520803                   2.5          0.0
# 1661790                   2.5          0.0
# 359292                    2.5          0.0

# %% [markdown]
# ### Renaming columns

# %%
minitaxi = minitaxi.rename(
    columns={
        'tpep_pickup_datetime': 'pickup', 
        'tpep_dropoff_datetime': 'dropoff'
    }
)
minitaxi.columns
# Out:
# Index(['pickup', 'dropoff', 'passenger_count', 'trip_distance', 'payment_type',
#        'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount', 'congestion_surcharge',
#        'Airport_fee'],
#       dtype='object')

# %% [markdown]
# ## Examine the correct data types (type conversion)

# %%
minitaxi.dtypes
# Out:
# pickup                   datetime64[us]
# dropoff                  datetime64[us]
# passenger_count                 float64
# trip_distance                   float64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# Airport_fee                     float64
# dtype: object

# %%
minitaxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1463982 to 871002
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pickup                 10000 non-null  datetime64[us]
#  1   dropoff                10000 non-null  datetime64[us]
#  2   passenger_count        9562 non-null   float64
#  3   trip_distance          10000 non-null  float64
#  4   payment_type           10000 non-null  int64
#  5   fare_amount            10000 non-null  float64
#  6   extra                  10000 non-null  float64
#  7   mta_tax                10000 non-null  float64
#  8   tip_amount             10000 non-null  float64
#  9   tolls_amount           10000 non-null  float64
#  10  improvement_surcharge  10000 non-null  float64
#  11  total_amount           10000 non-null  float64
#  12  congestion_surcharge   9562 non-null   float64
#  13  Airport_fee            9562 non-null   float64
# dtypes: datetime64[us](2), float64(11), int64(1)
# memory usage: 1.1 MB

# %%
# cast passenger_count to integers

minitaxi.loc[:, 'passenger_count'] = \
    minitaxi.loc[:, 'passenger_count'].astype(int)
minitaxi.dtypes
# Out:
# pickup                   datetime64[us]
# dropoff                  datetime64[us]
# passenger_count                   int32
# trip_distance                   float64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# Airport_fee                     float64
# dtype: object

# %% [markdown]
# ### Dropping rows with NA values

# %%
minitaxi = minitaxi.dropna()

# %%
minitaxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9562 entries, 1463982 to 871002
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pickup                 9562 non-null   datetime64[us]
#  1   dropoff                9562 non-null   datetime64[us]
#  2   passenger_count        9562 non-null   int32
#  3   trip_distance          9562 non-null   float64
#  4   payment_type           9562 non-null   int64
#  5   fare_amount            9562 non-null   float64
#  6   extra                  9562 non-null   float64
#  7   mta_tax                9562 non-null   float64
#  8   tip_amount             9562 non-null   float64
#  9   tolls_amount           9562 non-null   float64
#  10  improvement_surcharge  9562 non-null   float64
#  11  total_amount           9562 non-null   float64
#  12  congestion_surcharge   9562 non-null   float64
#  13  Airport_fee            9562 non-null   float64
# dtypes: datetime64[us](2), float64(10), int32(1), int64(1)
# memory usage: 1.1 MB

# %% [markdown]
# ## Creating new columns
#
# Let's calculate the following for each row:
#
# 1. elapsed time of the trip
# 2. the tip percentage
# 3. the total taxes, tolls, fees, and surcharges
# 4. the average speed of the taxi

# %%
minitaxi = minitaxi.assign(
    elapsed_time=lambda x: x.dropoff - x.pickup,
    cost_before_tip=lambda x: x.total_amount - x.tip_amount,
    tip_pct=lambda x: x.tip_amount / x.cost_before_tip, 
    fees=lambda x: x.cost_before_tip - x.fare_amount, 
    avg_speed=lambda x: x.trip_distance.div(
        x.elapsed_time.dt.total_seconds() / 60 / 60
    )
)

# %%
minitaxi.head(2)
# Out:
#                      pickup             dropoff  passenger_count  \
# 1463982 2024-01-17 18:24:02 2024-01-17 18:38:47                1
# 279981  2024-01-04 17:05:34 2024-01-04 17:15:20                5
#
#          trip_distance  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 1463982           1.92             1         14.9    2.5      0.5        2.25
# 279981            1.45             2         10.7    2.5      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 1463982           0.0                    1.0         23.65
# 279981            0.0                    1.0         17.20
#
#          congestion_surcharge  Airport_fee    elapsed_time  cost_before_tip  \
# 1463982                   2.5          0.0 0 days 00:14:45             21.4
# 279981                    2.5          0.0 0 days 00:09:46             17.2
#
#          tip_pct  fees  avg_speed
# 1463982  0.10514   6.5   7.810169
# 279981   0.00000   6.5   8.907850

# %% [markdown]
# *Notes*:
#
# - We used `lambda` functions to 1) avoid typing taxis repeatedly and 2) be able to access the `cost_before_tip` and `elapsed_time` columns in the same method that we create them.
# - To create a single new column, we can also use `df['new_col'] = <values>`.

# %% [markdown]
# ## Sorting by values

# %%
# sort by descending passenger count and pickups from earliest to latest
minitaxi.sort_values(['passenger_count', 'pickup'], ascending=[False, True]).head()
# Out:
#                     pickup             dropoff  passenger_count  \
# 42387  2024-01-01 14:08:46 2024-01-01 14:34:09                6
# 52534  2024-01-01 17:10:57 2024-01-01 17:24:38                6
# 65419  2024-01-01 21:42:16 2024-01-01 21:55:34                6
# 73092  2024-01-02 06:45:41 2024-01-02 06:54:41                6
# 191261 2024-01-03 16:17:08 2024-01-03 16:44:49                6
#
#         trip_distance  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 42387           11.10             1         46.4    5.0      0.5       10.93
# 52534            2.65             1         15.6    0.0      0.5        2.00
# 65419            1.41             1         13.5    1.0      0.5        3.70
# 73092            1.23             1         10.0    0.0      0.5        3.50
# 191261           4.00             2         26.1    2.5      0.5        0.00
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 42387            0.0                    1.0         65.58
# 52534            0.0                    1.0         21.60
# 65419            0.0                    1.0         22.20
# 73092            0.0                    1.0         17.50
# 191261           0.0                    1.0         32.60
#
#         congestion_surcharge  Airport_fee    elapsed_time  cost_before_tip  \
# 42387                    0.0         1.75 0 days 00:25:23            54.65
# 52534                    2.5         0.00 0 days 00:13:41            19.60
# 65419                    2.5         0.00 0 days 00:13:18            18.50
# 73092                    2.5         0.00 0 days 00:09:00            14.00
# 191261                   2.5         0.00 0 days 00:27:41            32.60
#
#          tip_pct  fees  avg_speed
# 42387   0.200000  8.25  26.237689
# 52534   0.102041  4.00  11.619976
# 65419   0.200000  5.00   6.360902
# 73092   0.250000  4.00   8.200000
# 191261  0.000000  6.50   8.669476

# %%
# pick out the 3 trips with largest timespan
minitaxi.nlargest(3, 'elapsed_time')
# Out:
#                      pickup             dropoff  passenger_count  \
# 2283617 2024-01-26 12:54:56 2024-01-27 12:49:06                1
# 2500524 2024-01-28 13:44:38 2024-01-29 13:31:56                5
# 1284138 2024-01-15 18:00:08 2024-01-16 17:45:02                1
#
#          trip_distance  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 2283617           1.75             2         21.2    0.0      0.5        0.00
# 2500524           0.52             2          7.2    0.0      0.5        0.00
# 1284138           3.10             1         19.8    0.0      0.5        2.38
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 2283617           0.0                    1.0         25.20
# 2500524           0.0                    1.0         11.20
# 1284138           0.0                    1.0         26.18
#
#          congestion_surcharge  Airport_fee    elapsed_time  cost_before_tip  \
# 2283617                   2.5          0.0 0 days 23:54:10             25.2
# 2500524                   2.5          0.0 0 days 23:47:18             11.2
# 1284138                   2.5          0.0 0 days 23:44:54             23.8
#
#          tip_pct  fees  avg_speed
# 2283617      0.0   4.0   0.073213
# 2500524      0.0   4.0   0.021859
# 1284138      0.1   4.0   0.130535

# %% [markdown]
# ## Working with index
# Currently the index is simply using the row numbers, but if we wish to work with the pickup times significantly, perhaps indexing by the datetime column is more effective.

# %%
minitaxi.index
# Out:
# Index([1463982,  279981, 1520803, 1661790,  359292, 2439708,  109810,   60123,
#         759802,  623340,
#        ...
#        1200054,  467157, 1864316,  100643, 2470600, 2081689, 1505987, 1923043,
#         371985,  871002],
#       dtype='int64', length=9562)

# %% [markdown]
# ### Setting index

# %%
minitaxi = minitaxi.set_index('pickup')
minitaxi.head(3)
# Out:
#                                 dropoff  passenger_count  trip_distance  \
# pickup
# 2024-01-17 18:24:02 2024-01-17 18:38:47                1           1.92
# 2024-01-04 17:05:34 2024-01-04 17:15:20                5           1.45
# 2024-01-18 11:13:37 2024-01-18 11:20:40                1           1.37
#
#                      payment_type  fare_amount  extra  mta_tax  tip_amount  \
# pickup
# 2024-01-17 18:24:02             1         14.9    2.5      0.5        2.25
# 2024-01-04 17:05:34             2         10.7    2.5      0.5        0.00
# 2024-01-18 11:13:37             1          9.3    0.0      0.5        2.66
#
#                      tolls_amount  improvement_surcharge  total_amount  \
# pickup
# 2024-01-17 18:24:02           0.0                    1.0         23.65
# 2024-01-04 17:05:34           0.0                    1.0         17.20
# 2024-01-18 11:13:37           0.0                    1.0         15.96
#
#                      congestion_surcharge  Airport_fee    elapsed_time  \
# pickup
# 2024-01-17 18:24:02                   2.5          0.0 0 days 00:14:45
# 2024-01-04 17:05:34                   2.5          0.0 0 days 00:09:46
# 2024-01-18 11:13:37                   2.5          0.0 0 days 00:07:03
#
#                      cost_before_tip  tip_pct  fees  avg_speed
# pickup
# 2024-01-17 18:24:02             21.4  0.10514   6.5   7.810169
# 2024-01-04 17:05:34             17.2  0.00000   6.5   8.907850
# 2024-01-18 11:13:37             13.3  0.20000   4.0  11.659574

# %% [markdown]
# ### Sorting by index

# %%
# sorting by indices
minitaxi = minitaxi.sort_index()
minitaxi.head()
# Out:
#                                 dropoff  passenger_count  trip_distance  \
# pickup
# 2024-01-01 00:05:48 2024-01-01 00:14:19                1           1.71
# 2024-01-01 00:08:20 2024-01-01 00:45:43                1           2.56
# 2024-01-01 00:09:47 2024-01-01 00:15:40                1           1.02
# 2024-01-01 00:14:19 2024-01-01 00:30:00                1           2.28
# 2024-01-01 00:14:29 2024-01-01 00:14:29                1           0.00
#
#                      payment_type  fare_amount  extra  mta_tax  tip_amount  \
# pickup
# 2024-01-01 00:05:48             1         11.4    1.0      0.5         4.1
# 2024-01-01 00:08:20             1         31.0    1.0      0.5         7.2
# 2024-01-01 00:09:47             2          7.9    1.0      0.5         0.0
# 2024-01-01 00:14:19             1         15.6    1.0      0.5         0.0
# 2024-01-01 00:14:29             2          3.0    3.5      0.5         0.0
#
#                      tolls_amount  improvement_surcharge  total_amount  \
# pickup
# 2024-01-01 00:05:48           0.0                    1.0          20.5
# 2024-01-01 00:08:20           0.0                    1.0          43.2
# 2024-01-01 00:09:47           0.0                    1.0          12.9
# 2024-01-01 00:14:19           0.0                    1.0          20.6
# 2024-01-01 00:14:29           0.0                    1.0           8.0
#
#                      congestion_surcharge  Airport_fee    elapsed_time  \
# pickup
# 2024-01-01 00:05:48                   2.5          0.0 0 days 00:08:31
# 2024-01-01 00:08:20                   2.5          0.0 0 days 00:37:23
# 2024-01-01 00:09:47                   2.5          0.0 0 days 00:05:53
# 2024-01-01 00:14:19                   2.5          0.0 0 days 00:15:41
# 2024-01-01 00:14:29                   2.5          0.0 0 days 00:00:00
#
#                      cost_before_tip  tip_pct  fees  avg_speed
# pickup
# 2024-01-01 00:05:48             16.4     0.25   5.0  12.046967
# 2024-01-01 00:08:20             36.0     0.20   5.0   4.108783
# 2024-01-01 00:09:47             12.9     0.00   5.0  10.402266
# 2024-01-01 00:14:19             20.6     0.00   5.0   8.722635
# 2024-01-01 00:14:29              8.0     0.00   5.0        NaN

# %% [markdown]
# Recall how we have used `[0:4]` to locate the rows indexed 0 to 4. Since we are indexing by datetime, we can select within time ranges.

# %% [markdown]
# ### Selecting by index

# %%
# selecting the taxi rides in the first 6 hours of the new year
minitaxi['2024-01-01 00:00':'2024-01-01 06:00']
# Out:
#                                 dropoff  passenger_count  trip_distance  \
# pickup
# 2024-01-01 00:05:48 2024-01-01 00:14:19                1           1.71
# 2024-01-01 00:08:20 2024-01-01 00:45:43                1           2.56
# 2024-01-01 00:09:47 2024-01-01 00:15:40                1           1.02
# 2024-01-01 00:14:19 2024-01-01 00:30:00                1           2.28
# 2024-01-01 00:14:29 2024-01-01 00:14:29                1           0.00
# ...                                 ...              ...            ...
# 2024-01-01 04:49:11 2024-01-01 05:08:49                1           5.30
# 2024-01-01 05:02:37 2024-01-01 05:12:34                1           2.90
# 2024-01-01 05:05:25 2024-01-01 05:28:31                1           4.03
# 2024-01-01 05:42:22 2024-01-01 05:55:44                1           3.70
# 2024-01-01 05:59:37 2024-01-01 06:02:22                1           0.74
#
#                      payment_type  fare_amount  extra  mta_tax  tip_amount  \
# pickup
# 2024-01-01 00:05:48             1         11.4    1.0      0.5        4.10
# 2024-01-01 00:08:20             1         31.0    1.0      0.5        7.20
# 2024-01-01 00:09:47             2          7.9    1.0      0.5        0.00
# 2024-01-01 00:14:19             1         15.6    1.0      0.5        0.00
# 2024-01-01 00:14:29             2          3.0    3.5      0.5        0.00
# ...                           ...          ...    ...      ...         ...
# 2024-01-01 04:49:11             1         24.7    1.0      0.5        5.94
# 2024-01-01 05:02:37             1         14.9    1.0      0.5        3.98
# 2024-01-01 05:05:25             4         27.5    1.0      0.5        0.00
# 2024-01-01 05:42:22             1         17.0    3.5      0.5        4.40
# 2024-01-01 05:59:37             2          5.8    1.0      0.5        0.00
#
#                      tolls_amount  improvement_surcharge  total_amount  \
# pickup
# 2024-01-01 00:05:48           0.0                    1.0         20.50
# 2024-01-01 00:08:20           0.0                    1.0         43.20
# 2024-01-01 00:09:47           0.0                    1.0         12.90
# 2024-01-01 00:14:19           0.0                    1.0         20.60
# 2024-01-01 00:14:29           0.0                    1.0          8.00
# ...                           ...                    ...           ...
# 2024-01-01 04:49:11           0.0                    1.0         35.64
# 2024-01-01 05:02:37           0.0                    1.0         23.88
# 2024-01-01 05:05:25           0.0                    1.0         32.50
# 2024-01-01 05:42:22           0.0                    1.0         26.40
# 2024-01-01 05:59:37           0.0                    1.0          8.30
#
#                      congestion_surcharge  Airport_fee    elapsed_time  \
# pickup
# 2024-01-01 00:05:48                   2.5          0.0 0 days 00:08:31
# 2024-01-01 00:08:20                   2.5          0.0 0 days 00:37:23
# 2024-01-01 00:09:47                   2.5          0.0 0 days 00:05:53
# 2024-01-01 00:14:19                   2.5          0.0 0 days 00:15:41
# 2024-01-01 00:14:29                   2.5          0.0 0 days 00:00:00
# ...                                   ...          ...             ...
# 2024-01-01 04:49:11                   2.5          0.0 0 days 00:19:38
# 2024-01-01 05:02:37                   2.5          0.0 0 days 00:09:57
# 2024-01-01 05:05:25                   2.5          0.0 0 days 00:23:06
# 2024-01-01 05:42:22                   2.5          0.0 0 days 00:13:22
# 2024-01-01 05:59:37                   0.0          0.0 0 days 00:02:45
#
#                      cost_before_tip  tip_pct  fees  avg_speed
# pickup
# 2024-01-01 00:05:48             16.4     0.25   5.0  12.046967
# 2024-01-01 00:08:20             36.0     0.20   5.0   4.108783
# 2024-01-01 00:09:47             12.9     0.00   5.0  10.402266
# 2024-01-01 00:14:19             20.6     0.00   5.0   8.722635
# 2024-01-01 00:14:29              8.0     0.00   5.0        NaN
# ...                              ...      ...   ...        ...
# 2024-01-01 04:49:11             29.7     0.20   5.0  16.196944
# 2024-01-01 05:02:37             19.9     0.20   5.0  17.487437
# 2024-01-01 05:05:25             32.5     0.00   5.0  10.467532
# 2024-01-01 05:42:22             22.0     0.20   5.0  16.608479
# 2024-01-01 05:59:37              8.3     0.00   2.5  16.145455
#
# [77 rows x 18 columns]

# %% [markdown]
# ### Resetting index
# We can revert any specific column index back to row numbers, **but** notice that by setting and resetting index you lose the original row numbers.

# %%
minitaxi = minitaxi.reset_index()
minitaxi.head()
# Out:
#    index              pickup             dropoff  passenger_count  \
# 0      0 2024-01-01 00:05:48 2024-01-01 00:14:19                1
# 1      1 2024-01-01 00:08:20 2024-01-01 00:45:43                1
# 2      2 2024-01-01 00:09:47 2024-01-01 00:15:40                1
# 3      3 2024-01-01 00:14:19 2024-01-01 00:30:00                1
# 4      4 2024-01-01 00:14:29 2024-01-01 00:14:29                1
#
#    trip_distance  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0           1.71             1         11.4    1.0      0.5         4.1
# 1           2.56             1         31.0    1.0      0.5         7.2
# 2           1.02             2          7.9    1.0      0.5         0.0
# 3           2.28             1         15.6    1.0      0.5         0.0
# 4           0.00             2          3.0    3.5      0.5         0.0
#
#    tolls_amount  improvement_surcharge  total_amount  congestion_surcharge  \
# 0           0.0                    1.0          20.5                   2.5
# 1           0.0                    1.0          43.2                   2.5
# 2           0.0                    1.0          12.9                   2.5
# 3           0.0                    1.0          20.6                   2.5
# 4           0.0                    1.0           8.0                   2.5
#
#    Airport_fee    elapsed_time  cost_before_tip  tip_pct  fees  avg_speed
# 0          0.0 0 days 00:08:31             16.4     0.25   5.0  12.046967
# 1          0.0 0 days 00:37:23             36.0     0.20   5.0   4.108783
# 2          0.0 0 days 00:05:53             12.9     0.00   5.0  10.402266
# 3          0.0 0 days 00:15:41             20.6     0.00   5.0   8.722635
# 4          0.0 0 days 00:00:00              8.0     0.00   5.0        NaN

# %% [markdown]
# ## Practice 2
#
# Using the `meteor` dataset,
#
# 1. cast the `year` column to an integer column.
# 2. create a new column indicating whether the meteorite was observed falling before 1970.
# 3. set the index to the id column and extract all the rows with IDs between 10,036 and 10,040 (inclusive) with `loc[]`.
# 4. examine the `year` column to see if there are any data errors.
